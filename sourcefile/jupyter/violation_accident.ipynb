# %%
#2019년
# gubun: S1203
# mid: S1203
# sYear: 2019
# eYear: 2019
# sido: 11000
# jijace: 11680 11740 #지자체
# kind1: s104
# kind2: s1041
# cartype: carall

#11740강동구  11305강북구   11500강서구     11620관악구  11215광진구 11530구로구  금천구 11545 노원구11350 도봉구11320 동대문구11230
                   #11590 동작구  11440마포구  11410서대문구 11650서초구  11200성동구  11290성북구 11710송파구 11470양천구  11560영등포 11170용산구
                   #11380 은평구  11110종로구  11140중구 11140중량구

# %%
jijace_list=[["강남구" , 11680] , ["강동구" ,11740], ["강북구" , 11305], ["강서구" , 11500],  ["관악구", 11620], ["광진구" , 11215], ["구로구" ,11530],
            ["금천구",11545], ["노원구" , 11350] ,["도봉구",11320], ["동대문구",11230], ["동작구" , 11590], ["마포구" ,11440] , ["서대문구" ,11410] , ["서초구", 11650],
            ["성동구" , 11200], ["성북구" , 11290], ["송파구" , 11710], ["양천구" ,11470], ["영등포구" , 11560], ["용산구" , 11170], ["은평구" , 11380],
            ["종로구", 11110] , ["중구" , 11140], ["중랑구",11260]]

# %%
year_list=[2018,2019,2020,2021,2022]

# %%
#2018년
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS 
from tqdm import tqdm
url="https://tmacs.kotsa.or.kr/web/TG/TG200/TG2100S/Tgsearch01_AJAX.jsp"
payload={"gubun":"S1203", 
"mid":"S1203",
"sYear":"2018", 
"eYear":"2018", 
"sido":"11000",
"jijace":"11680",  
"kind1":"s104",
"kind2":"s1041",
"cartype":"carall"}

# data = r.text

# %%
# r = requests.post(url, data=payload)
# bs = eval(r.text)
# df = pd.DataFrame(bs)
# pd.set_option('display.max_columns', None)
# df
# Out:
#    JIJACE_NM  CHISA  ACC_HUM SIDO_CD GUBUN_NM  SLTWD_CNT  SERI_ACC SIDO_NM  \
# 0        강남구    0.0      111   11000       승용         70        27      서울
# 1        강남구    0.0        2   11000       화물          1         1      서울
# 2        강남구    0.0       11   11000       이륜          9         2      서울
# 3        강남구    0.0        1   11000      원동기          0         1      서울
# 4        강남구    0.0        4   11000      자전거          4         0      서울
# ..       ...    ...      ...     ...      ...        ...       ...     ...
# 62       강남구    0.0        8   11000       이륜          5         0      서울
# 63       강남구    0.0        1   11000      원동기          0         1      서울
# 64       강남구    0.0        4   11000      자전거          1         1      서울
# 65       강남구    0.0        2   11000       기타          1         0      서울
# 66       강남구    0.0        1   11000       승용          0         1      서울
#
# ...

# %%
total_df=pd.DataFrame()
for i in tqdm(range(len(jijace_list))):
    for j in range(len(year_list)):
        payload["sYear"]=year_list[j]
        payload["eYear"]=year_list[j]
        payload["jijace"]=jijace_list[i][1]
            # print(year_list[j])
            # print(jijace_list[i][1])
        r = requests.post(url, data=payload)
        bs = eval(r.text)
        df = pd.DataFrame(bs)
        df["YEAR"]=year_list[j]
        df["BASE_CATEGORY"]= "위반"
        
        total_df = pd.concat([total_df, df], axis = 0)
            # pd.set_option('display.max_columns', None)
            # for k in range(len(data)):
            #     SIDO_NM_list.append(data[k]["SIDO_NM"])
            #     JIJACE_NM_list.append(data[k]["JIJACE_NM"])
            #     BASE_NAME_list.append(data[k]["BASE_NAME"])
            #     GUBUN_NM_list.append(data[k]["GUBUN_NM"])
            #     ACC_CNT_list.append(data[k]["ACC_CNT"])
            #     BIG_CNT_list.append(data[k]["BIG_CNT"])
            #     PSGT_CNT_list.append(data[k]["PSGT_CNT"])
            #     TRK_CNT_list.append(data[k]["TRK_CNT"])
            #     DEATH_CNT_list.append(data[k]["DEATH_CNT"])
            #     CHISA_list.append(data[k]["CHISA"])
            #     YEAR_list.append(year_list[j])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 25/25 [01:20<00:00,  3.21s/it]

# %%
total_df
# Out:
#    JIJACE_NM  CHISA  ACC_HUM SIDO_CD     GUBUN_NM  SLTWD_CNT  SERI_ACC  \
# 0        강남구    0.0      111   11000           승용         70        27
# 1        강남구    0.0        2   11000           화물          1         1
# 2        강남구    0.0       11   11000           이륜          9         2
# 3        강남구    0.0        1   11000          원동기          0         1
# 4        강남구    0.0        4   11000          자전거          4         0
# ..       ...    ...      ...     ...          ...        ...       ...
# 72       중랑구    0.0        9   11000           이륜          6         1
# 73       중랑구    0.0        1   11000          원동기          1         0
# 74       중랑구    0.0       11   11000          자전거          6         4
# 75       중랑구    0.0        1   11000  개인형이동수단(PM)          0         1
# 76       중랑구    0.0        2   11000           기타          1         0
#
#    SIDO_NM AC_MODE CRT_JIJACE_CD BASE_NAME  BIG_CNT  PSGT_CNT  WND_ACC  \
# ...

# %%
# total_df.reset_index(inplace=True)
total_df.reset_index(drop=True, inplace=True)

# %%
# total_df.drop('index',axis=1)
total_df
# Out:
#      JIJACE_NM  CHISA  ACC_HUM SIDO_CD     GUBUN_NM  SLTWD_CNT  SERI_ACC  \
# 0          강남구    0.0      111   11000           승용         70        27
# 1          강남구    0.0        2   11000           화물          1         1
# 2          강남구    0.0       11   11000           이륜          9         2
# 3          강남구    0.0        1   11000          원동기          0         1
# 4          강남구    0.0        4   11000          자전거          4         0
# ...        ...    ...      ...     ...          ...        ...       ...
# 8011       중랑구    0.0        9   11000           이륜          6         1
# 8012       중랑구    0.0        1   11000          원동기          1         0
# 8013       중랑구    0.0       11   11000          자전거          6         4
# 8014       중랑구    0.0        1   11000  개인형이동수단(PM)          0         1
# 8015       중랑구    0.0        2   11000           기타          1         0
#
#      SIDO_NM AC_MODE CRT_JIJACE_CD BASE_NAME  BIG_CNT  PSGT_CNT  WND_ACC  \
# ...

# %%
total_df.columns
# Out:
# Index(['JIJACE_NM', 'CHISA', 'ACC_HUM', 'SIDO_CD', 'GUBUN_NM', 'SLTWD_CNT',
#        'SERI_ACC', 'SIDO_NM', 'AC_MODE', 'CRT_JIJACE_CD', 'BASE_NAME',
#        'BIG_CNT', 'PSGT_CNT', 'WND_ACC', 'ACC_CNT', 'TRK_CNT', 'DEATH_CNT',
#        'BASE_CODE', 'WND_CNT', 'DEATH_ACC', 'GUBUN', 'SERI_CNT', 'SLTWD_ACC',
#        'YEAR', 'BASE_CATEGORY'],
#       dtype='object')

# %%
import pymysql
con =pymysql.connect(host='ip', user='id', password='pw', db='encore6', charset='utf8')
cur = con.cursor()
cur.execute("show tables")
# Out:
# 2

# %%
total_df.columns
# Out:
# Index(['JIJACE_NM', 'CHISA', 'ACC_HUM', 'SIDO_CD', 'GUBUN_NM', 'SLTWD_CNT',
#        'SERI_ACC', 'SIDO_NM', 'AC_MODE', 'CRT_JIJACE_CD', 'BASE_NAME',
#        'BIG_CNT', 'PSGT_CNT', 'WND_ACC', 'ACC_CNT', 'TRK_CNT', 'DEATH_CNT',
#        'BASE_CODE', 'WND_CNT', 'DEATH_ACC', 'GUBUN', 'SERI_CNT', 'SLTWD_ACC',
#        'YEAR', 'BASE_CATEGORY'],
#       dtype='object')

# %%
total_df
# Out:
#      JIJACE_NM  CHISA  ACC_HUM SIDO_CD     GUBUN_NM  SLTWD_CNT  SERI_ACC  \
# 0          강남구    0.0      111   11000           승용         70        27
# 1          강남구    0.0        2   11000           화물          1         1
# 2          강남구    0.0       11   11000           이륜          9         2
# 3          강남구    0.0        1   11000          원동기          0         1
# 4          강남구    0.0        4   11000          자전거          4         0
# ...        ...    ...      ...     ...          ...        ...       ...
# 8011       중랑구    0.0        9   11000           이륜          6         1
# 8012       중랑구    0.0        1   11000          원동기          1         0
# 8013       중랑구    0.0       11   11000          자전거          6         4
# 8014       중랑구    0.0        1   11000  개인형이동수단(PM)          0         1
# 8015       중랑구    0.0        2   11000           기타          1         0
#
#      SIDO_NM AC_MODE CRT_JIJACE_CD BASE_NAME  BIG_CNT  PSGT_CNT  WND_ACC  \
# ...

# %%
type(df.loc[0,"BASE_CODE"])
# Out:
# str

# %%
sql= """CREATE Table violation_accident
(
    `JIJACE_NM` VARCHAR(30),
    `CHISA` FLOAT,
    `ACC_HUM` INT,
    `SIDO_CD` INT,
    `GUBUN_NM` VARCHAR(30),
    `SLTWD_CNT` INT,
    `SERI_ACC` INT,
    `SIDO_NM` VARCHAR(10),
    `AC_MODE` VARCHAR(4),
    `CRT_JIJACE_CD` INT ,
    `BASE_NAME` VARCHAR(30),
    `BIG_CNT` INT,
    `PSGT_CNT` INT,
    `WND_ACC` INT,
    `ACC_CNT` INT,
    `TRK_CNT` INT,
    `DEATH_CNT` INT,
    `BASE_CODE` VARCHAR(10),
    `WND_CNT` INT,
    `DEATH_ACC` INT,
    `GUBUN` VARCHAR(5),
    `SERI_CNT` INT,
    `SLTWD_ACC` INT,
    `YEAR` INT,
    `BASE_CATEGORY` VARCHAR(10)
)"""
cur.execute(sql)
con.commit()
# insert_sql="INSERT  INTO dataset2 VALUES (%s, %s, %s, %s, %s,%s, %s, %s, %s, %s)"
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[177], line 29
#       1 sql= """CREATE Table violation_accident
#       2 (
#       3     `JIJACE_NM` VARCHAR(30),
#    (...)
#      27     `BASE_CATEGORY` VARCHAR(10)
#      28 )"""
# ---> 29 cur.execute(sql)
#      30 con.commit()
#      31 # insert_sql="INSERT  INTO dataset2 VALUES (%s, %s, %s, %s, %s,%s, %s, %s, %s, %s)"
#
# File ~/.local/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/.local/lib/python3.10/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
# ...

# %%
insert_sql="INSERT INTO violation_accident VALUES (%s, %s, %s, %s, %s,%s, %s, %s, %s, %s,%s,%s, %s, %s, %s, %s,%s, %s, %s, %s, %s,%s,%s,%s,%s)"

# %%
def tmp(x):
    global var_x 
    var_x = x
    cur.execute(insert_sql, x.tolist())
    return 0

# %%
# total_df.apply(tmp,axis=1)

# %%
total_df.apply(lambda x : cur.execute(insert_sql,x.tolist()),axis=1)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8011    1
# 8012    1
# 8013    1
# 8014    1
# 8015    1
# Length: 8016, dtype: int64

# %%
con.commit()

# %%
import folium

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="cartodb positron")

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import json

# %%
geo_str = requests.get("https://t1.daumcdn.net/cfile/tistory/272C224C58B4BD540B").json()

# %%
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
# ...

# %%
data = total_df.groupby(['JIJACE_NM'],as_index=False)[['ACC_HUM']].sum()
m = folium.Choropleth(geo_str, 
                  data = data,
                  columns=['JIJACE_NM', 'ACC_HUM'],
                  fill_color="PuRd",
                  key_on="feature.id").add_to(map)
                  
# df2 = df.groupby(['country','city'],as_index=False)[['tmp']].sum().sort_values(by=['country','city']).rename(columns={"tmp":"atv"})

# %%
data.head(1)
# Out:
#   JIJACE_NM  ACC_HUM
# 0       강남구    25642

# %%
m = folium.Choropleth(geo_str, 
                  data = data,
                  columns=['JIJACE_NM', 'ACC_HUM'],
                  fill_color="PuRd",
                  key_on="feature.id").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# data=r.json()

# %%
# print(data[0].keys())

# %%
# 'JIJACE_NM',
# 'CHISA', 
# 'ACC_HUM', 
# 'SIDO_CD', 
# 'GUBUN_NM', 
# 'SLTWD_CNT', 
# 'SERI_ACC', 
# 'SIDO_NM', 
# 'AC_MODE', 
# 'CRT_JIJACE_CD', 
# 'BASE_NAME',
# 'BIG_CNT', 'PSGT_CNT', 'WND_ACC', 'ACC_CNT', 'TRK_CNT', 'DEATH_CNT', 'BASE_CODE', 'WND_CNT', 'DEATH_ACC', 'GUBUN', 'SERI_CNT', 'SLTWD_ACC'

# %%
#


#  'SIDO_CD': '11000',
#  'AC_MODE': 'A',
#  'CRT_JIJACE_CD': '11260',

#  'BASE_CODE': '01',
#  'GUBUN': '01',

# %%
# len(jijace_list)

# %%
# SIDO_NM_list=[]
# JIJACE_NM_list=[]
# BASE_NAME_list=[]
# GUBUN_NM_list=[]
# ACC_CNT_list=[]
# BIG_CNT_list=[]
# PSGT_CNT_list=[]
# TRK_CNT_list=[]
# DEATH_CNT_list=[]
# CHISA_list=[]
# YEAR_list=[]

# %%
# for i in tqdm(range(len(jijace_list))):
#     for j in range(len(year_list)):
#         try:
            
#             payload["sYear"]=year_list[j]
#             payload["eYear"]=year_list[j]
#             payload["jijace"]=jijace_list[i][1]
#             # print(year_list[j])
#             # print(jijace_list[i][1])
#             r = requests.post(url, data=payload)
#             data = r.json()
#             for k in range(len(data)):
#                 SIDO_NM_list.append(data[k]["SIDO_NM"])
#                 JIJACE_NM_list.append(data[k]["JIJACE_NM"])
#                 BASE_NAME_list.append(data[k]["BASE_NAME"])
#                 GUBUN_NM_list.append(data[k]["GUBUN_NM"])
#                 ACC_CNT_list.append(data[k]["ACC_CNT"])
#                 BIG_CNT_list.append(data[k]["BIG_CNT"])
#                 PSGT_CNT_list.append(data[k]["PSGT_CNT"])
#                 TRK_CNT_list.append(data[k]["TRK_CNT"])
#                 DEATH_CNT_list.append(data[k]["DEATH_CNT"])
#                 CHISA_list.append(data[k]["CHISA"])
#                 YEAR_list.append(year_list[j])

                
#         except:
#             print(year_list[j]+" "+jijace_list[i][1])
      
#     #시도 SIDO_NM
#     #지자체 JIJACE_NM
#     #위반유형 BASE_NAME
#     #차량종류 GUBUN_NM
#     #발생건수 ACC_CNT
#     #대형사고 BIG_CNT
#     #중대가여객 PSGT_CNT
#     #중대사화물 TRK_CNT
#     #사망자수 DEATH_CNT
#     #치사 CHISA
#         # data=r.text
#         # break
#     # break

# %%
# total_dict={"YEAR" 'JIJACE_NM'  'CHISA' 'ACC_HUM' 'SIDO_CD' 'GUBUN_NM'  'SLTWD_CNT'

# %%
# total_dict={"YEAR" : YEAR_list, "SIDO_NM" : SIDO_NM_list , "JIJACE_NM" : JIJACE_NM_list, "BASE_NAME" :BASE_NAME_list, "GUBUN_NM" :GUBUN_NM_list,
#             "ACC_CNT": ACC_CNT_list, "BIG_CNT" : BIG_CNT_list, "PSGT_CNT": PSGT_CNT_list, "TRK_CNT" : TRK_CNT_list,
#             "DEATH_CNT": DEATH_CNT_list, "CHISA":CHISA_list}

# %%
# print(total_dict)

# %%
# total_df=pd.DataFrame(total_dict)

# %%
# print(total_df)

# %%
import pickle
with open("./total_df.pkl","wb") as f:
     pickle.dump(total_df,f)

# %%
# total_dict={"YEAR" : YEAR_list, "SIDO_NM" : SIDO_NM_list , "JIJACE_NM" : JIJACE_NM_list, "BASE_NAME" :BASE_NAME_list, "GUBUN_NM" :GUBUN_NM_list,
#             "ACC_CNT": ACC_CNT_list, "BIG_CNT" : BIG_CNT_list, "PSGT_CNT": PSGT_CNT_list, "TRK_CNT" : TRK_CNT_list,
#             "DEATH_CNT": DEATH_CNT_list, "CHISA":CHISA_list}

# %%
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data = r.json()

# %%
# data

# %%
# len(data)

# %%
# for i in range(len(data)):
#     SIDO_NM_list.append(data[i]["SIDO_NM"])
#     JIJACE_NM_list.append(data[i]["JIJACE_NM"])
#     BASE_NAME_list.append(data[i]["BASE_NAME"])
#     GUBUN_NM_list.append(data[i]["GUBUN_NM"])
#     ACC_CNT_list.append(data[i]["ACC_CNT"])
#     BIG_CNT_list.append(data[i]["BIG_CNT"])
#     PSGT_CNT_list.append(data[i]["PSGT_CNT"])
#     TRK_CNT_list.append(data[i]["TRK_CNT"])
#     DEATH_CNT_list.append(data[i]["DEATH_CNT"])
#     CHISA_list.append(data[i]["CHISA"])
#     #시도 SIDO_NM
#     #지자체 JIJACE_NM
#     #위반유형 BASE_NAME
#     #차량종류 GUBUN_NM
#     #발생건수 ACC_CNT
#     #대형사고 BIG_CNT
#     #중대가여객 PSGT_CNT
#     #중대사화물 TRK_CNT
#     #사망자수 DEATH_CNT
#     #치사 CHISA
