# %%
import glob

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
glob.glob("./bic_s/*.xlsx")
# Out:
# ['./bic_s\\서울특별시 공공자전거 이용정보(월별)_19.01.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.02.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.03.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.04.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.05.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.06.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.07.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.08.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.09.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.10.xlsx',
#  './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.11.xlsx']

# %%
target = glob.glob("./bic_s/*.xlsx")

# %%
target[0]
# Out:
# './bic_s\\서울특별시 공공자전거 이용정보(월별)_19.01.xlsx'

# %%
len(target)
# Out:
# 11

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('./bic_s/서울특별시 공공자전거 이용정보(월별)_19.01.xlsx')
# Out:
#             대여일자  대여소번호             대여소  대여구분코드 성별    연령대코드  이용건수      운동량  \
# 0     2019-01-01      3            중랑센터  일일(회원)  M  AGE_003    12   288.87
# 1     2019-01-01      3            중랑센터  일일(회원)  M  AGE_004     8   424.63
# 2     2019-01-01      3            중랑센터  일일(회원)  M  AGE_005    27  4579.48
# 3     2019-01-01      3            중랑센터      정기  M  AGE_003    17   3438.8
# 4     2019-01-01      5        상암센터 정비실  일일(회원)  M  AGE_004     1    78.31
# ...          ...    ...             ...     ... ..      ...   ...      ...
# 34814 2019-01-01  99999  99999. 영남단말기정비      정기  M  AGE_002    49  3157.09
# 34815 2019-01-01  99999  99999. 영남단말기정비      정기  M  AGE_003    80  6438.28
# 34816 2019-01-01  99999  99999. 영남단말기정비      정기  M  AGE_004    35  2359.89
# 34817 2019-01-01  99999  99999. 영남단말기정비      정기  M  AGE_005    30  1421.88
# 34818 2019-01-01  99999  99999. 영남단말기정비      정기  M  AGE_006     3   253.64
#
#          탄소량  이동거리(M)  이동시간(분)
# 0       2.25     9690      117
# ...

# %%
df_1_11 = pd.DataFrame()

# %%
from tqdm import tqdm

# %%
for x in tqdm(range(0, 11)):
    # print(target[x])
    df_1_11 = pd.concat([df_1_11, pd.read_excel(target[x])])
# Out:
# 100%|██████████| 11/11 [01:12<00:00,  6.56s/it]

# %%
df_1_11
# Out:
#             대여일자  대여소번호               대여소  대여구분코드 성별    연령대코드  이용건수      운동량  \
# 0     2019-01-01      3              중랑센터  일일(회원)  M  AGE_003    12   288.87
# 1     2019-01-01      3              중랑센터  일일(회원)  M  AGE_004     8   424.63
# 2     2019-01-01      3              중랑센터  일일(회원)  M  AGE_005    27  4579.48
# 3     2019-01-01      3              중랑센터      정기  M  AGE_003    17   3438.8
# 4     2019-01-01      5          상암센터 정비실  일일(회원)  M  AGE_004     1    78.31
# ...          ...    ...               ...     ... ..      ...   ...      ...
# 63908 2019-11-01   9998  9998. 영남주차장 정비센터      정기  M  AGE_004     8   244.33
# 63909 2019-11-01  99998     99998. 상암단말정비      정기     AGE_005     2        0
# 63910 2019-11-01  99999    99999. 영남단말기정비      정기     AGE_002     6   2110.9
# 63911 2019-11-01  99999    99999. 영남단말기정비      정기     AGE_004    10  1304.51
# 63912 2019-11-01  99999    99999. 영남단말기정비      정기  M  AGE_004    17  2526.53
#
#          탄소량  이동거리(M)  이동시간(분)
# ...

# %%
df_1_11.head(1)
# Out:
#         대여일자  대여소번호   대여소  대여구분코드 성별    연령대코드  이용건수     운동량   탄소량  이동거리(M)  \
# 0 2019-01-01      3  중랑센터  일일(회원)  M  AGE_003    12  288.87  2.25     9690
#
#    이동시간(분)
# 0      117

# %%
df_1_11['대여일자'] = df_1_11['대여일자'].apply(lambda x: str(x)[:7])

# %%
pd.read_csv('./bic_s/서울특별시 공공자전거 이용정보(월별)_19.12.csv', encoding='cp949')
# Out:
#           대여일자  대여소번호            대여소명  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0      2019-12      3            중랑센터  일일(회원)   M  AGE_003     7  1208.87
# 1      2019-12      3            중랑센터  일일(회원)   M  AGE_004     2        0
# 2      2019-12      3            중랑센터      정기   M  AGE_005     5   110.02
# 3      2019-12      5        상암센터 정비실  일일(회원)  \N  AGE_005     1        0
# 4      2019-12      5        상암센터 정비실  일일(회원)   M  AGE_004     5    427.8
# ...        ...    ...             ...     ...  ..      ...   ...      ...
# 53800  2019-12   9999          시스템관리팀  일일(회원)  \N  AGE_002     1       \N
# 53801  2019-12  99998   99998. 상암단말정비      정기  \N  AGE_005     3     5.11
# 53802  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_002     1        0
# 53803  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_004     2    44.78
# 53804  2019-12  99999  99999. 영남단말기정비      정기   M  AGE_004    19  9186.81
#
#          탄소량    이동거리  이용시간
# 0      10.11   43610   118
# ...

# %%
df_12 = pd.read_csv('./bic_s/서울특별시 공공자전거 이용정보(월별)_19.12.csv', encoding='cp949')

# %%
df_12
# Out:
#           대여일자  대여소번호            대여소명  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0      2019-12      3            중랑센터  일일(회원)   M  AGE_003     7  1208.87
# 1      2019-12      3            중랑센터  일일(회원)   M  AGE_004     2        0
# 2      2019-12      3            중랑센터      정기   M  AGE_005     5   110.02
# 3      2019-12      5        상암센터 정비실  일일(회원)  \N  AGE_005     1        0
# 4      2019-12      5        상암센터 정비실  일일(회원)   M  AGE_004     5    427.8
# ...        ...    ...             ...     ...  ..      ...   ...      ...
# 53800  2019-12   9999          시스템관리팀  일일(회원)  \N  AGE_002     1       \N
# 53801  2019-12  99998   99998. 상암단말정비      정기  \N  AGE_005     3     5.11
# 53802  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_002     1        0
# 53803  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_004     2    44.78
# 53804  2019-12  99999  99999. 영남단말기정비      정기   M  AGE_004    19  9186.81
#
#          탄소량    이동거리  이용시간
# 0      10.11   43610   118
# ...

# %%
df_12.rename(columns={'이동거리' : '이동거리(M)', '이용시간' : '이동시간(분)', '대여소명' : '대여소'}, inplace=True)

# %%
pd.concat([df_1_11, df_12], axis=0)
# Out:
#           대여일자  대여소번호             대여소  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0      2019-01      3            중랑센터  일일(회원)   M  AGE_003    12   288.87
# 1      2019-01      3            중랑센터  일일(회원)   M  AGE_004     8   424.63
# 2      2019-01      3            중랑센터  일일(회원)   M  AGE_005    27  4579.48
# 3      2019-01      3            중랑센터      정기   M  AGE_003    17   3438.8
# 4      2019-01      5        상암센터 정비실  일일(회원)   M  AGE_004     1    78.31
# ...        ...    ...             ...     ...  ..      ...   ...      ...
# 53800  2019-12   9999          시스템관리팀  일일(회원)  \N  AGE_002     1       \N
# 53801  2019-12  99998   99998. 상암단말정비      정기  \N  AGE_005     3     5.11
# 53802  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_002     1        0
# 53803  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_004     2    44.78
# 53804  2019-12  99999  99999. 영남단말기정비      정기   M  AGE_004    19  9186.81
#
#          탄소량  이동거리(M)  이동시간(분)
# 0       2.25     9690      117
# ...

# %%
df_2019 = pd.concat([df_1_11, df_12], axis=0)

# %%
df_2019
# Out:
#           대여일자  대여소번호             대여소  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0      2019-01      3            중랑센터  일일(회원)   M  AGE_003    12   288.87
# 1      2019-01      3            중랑센터  일일(회원)   M  AGE_004     8   424.63
# 2      2019-01      3            중랑센터  일일(회원)   M  AGE_005    27  4579.48
# 3      2019-01      3            중랑센터      정기   M  AGE_003    17   3438.8
# 4      2019-01      5        상암센터 정비실  일일(회원)   M  AGE_004     1    78.31
# ...        ...    ...             ...     ...  ..      ...   ...      ...
# 53800  2019-12   9999          시스템관리팀  일일(회원)  \N  AGE_002     1       \N
# 53801  2019-12  99998   99998. 상암단말정비      정기  \N  AGE_005     3     5.11
# 53802  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_002     1        0
# 53803  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_004     2    44.78
# 53804  2019-12  99999  99999. 영남단말기정비      정기   M  AGE_004    19  9186.81
#
#          탄소량  이동거리(M)  이동시간(분)
# 0       2.25     9690      117
# ...

# %%
df_2019 = df_2019.iloc[:, [0, 1, 6]]

# %%
df_2019
# Out:
#           대여일자  대여소번호  이용건수
# 0      2019-01      3    12
# 1      2019-01      3     8
# 2      2019-01      3    27
# 3      2019-01      3    17
# 4      2019-01      5     1
# ...        ...    ...   ...
# 53800  2019-12   9999     1
# 53801  2019-12  99998     3
# 53802  2019-12  99999     1
# 53803  2019-12  99999     2
# 53804  2019-12  99999    19
#
# [675209 rows x 3 columns]

# %%
df_2019.columns
# Out:
# Index(['대여일자', '대여소번호', '이용건수'], dtype='object')

# %%
cnt_2019 = df_2019.groupby(['대여일자'], as_index=False)[['이용건수']].sum()

# %%
cnt_2019
# Out:
#        대여일자     이용건수
# 0   2019-01   495573
# 1   2019-02   471536
# 2   2019-03   904788
# 3   2019-04  1468848
# 4   2019-05  2151064
# 5   2019-06  2293879
# 6   2019-07  2164086
# 7   2019-08  2101184
# 8   2019-09  2084222
# 9   2019-10  2436401
# 10  2019-11  1537269
# 11  2019-12   882078

# %%
CycleRentUseMonth_2019 = df_2019.groupby(['대여일자', '대여소번호'], as_index=False)[['이용건수']].sum()

# %%
CycleRentUseMonth_2019
# Out:
#           대여일자  대여소번호  이용건수
# 0      2019-01      3    64
# 1      2019-01      5     2
# 2      2019-01    101   241
# 3      2019-01    102   785
# 4      2019-01    103   623
# ...        ...    ...   ...
# 18479  2019-12   9997    20
# 18480  2019-12   9998    12
# 18481  2019-12   9999     1
# 18482  2019-12  99998     3
# 18483  2019-12  99999    22
#
# [18484 rows x 3 columns]

# %%
CycleRentUseMonth_2019.to_pickle('CycleRentUseMonth_2019.pkl')
